# %% [markdown]
# # **Problem Statement:**

# %% [markdown]
# Convolutional neural network (CNN)
#
# Use MNIST Fashion Dataset and create a classifier to classify fashion clothing into
# categories.

# %% [markdown]
# About the dataset:
#
# Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. Zalando intends Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.

# %% [markdown]
# Import the libraries

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# # **Import the fashion MNIST dataset**

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # **EDA:**

# %% [markdown]
# Preprocessing of data:

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# # **Explore the data:**

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# # **Feature Engineering:**

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # **Model Building/ training and testing:**

# %% [markdown]
# Build the model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Train the model

# %%
model.fit(train_images, train_labels, epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4989 - accuracy: 0.8260
# Epoch 2/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3787 - accuracy: 0.8633
# Epoch 3/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3406 - accuracy: 0.8758
# Epoch 4/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3147 - accuracy: 0.8839
# Epoch 5/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2952 - accuracy: 0.8896
# Epoch 6/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2789 - accuracy: 0.8969
# Epoch 7/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2667 - accuracy: 0.8998
# Epoch 8/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2547 - accuracy: 0.9045
# Epoch 9/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2450 - accuracy: 0.9087
# Epoch 10/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2391 - accuracy: 0.9099
# Epoch 11/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2294 - accuracy: 0.9143
# Epoch 12/30
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2225 - accuracy: 0.9161
# Epoch 13/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2174 - accuracy: 0.9186
# Epoch 14/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2100 - accuracy: 0.9211
# Epoch 15/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2041 - accuracy: 0.9231
# Epoch 16/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1958 - accuracy: 0.9272
# Epoch 17/30
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1910 - accuracy: 0.9275
# Epoch 18/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1888 - accuracy: 0.9284
# Epoch 19/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1819 - accuracy: 0.9319
# Epoch 20/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1763 - accuracy: 0.9336
# Epoch 21/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1745 - accuracy: 0.9337
# Epoch 22/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1689 - accuracy: 0.9357
# Epoch 23/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1653 - accuracy: 0.9385
# Epoch 24/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1612 - accuracy: 0.9391
# Epoch 25/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1563 - accuracy: 0.9407
# Epoch 26/30
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1543 - accuracy: 0.9416
# Epoch 27/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1513 - accuracy: 0.9428
# Epoch 28/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1482 - accuracy: 0.9443
# Epoch 29/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1452 - accuracy: 0.9447
# Epoch 30/30
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1417 - accuracy: 0.9467

# %% [markdown]
# # **Model Evaluation:**

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3925 - accuracy: 0.8874 - 636ms/epoch - 2ms/step
#
# Test accuracy: 0.8873999714851379

# %% [markdown]
# Make predictions

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
predictions[0]
# Out:
# array([8.3018659e-09, 8.1000742e-17, 1.2502894e-14, 1.4957120e-19,
#        4.6748604e-15, 3.1571304e-07, 1.9845548e-13, 4.1036733e-04,
#        5.2788529e-15, 9.9958926e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Verify predictions

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# Use the trained model

# %%
# Grab an image from the test dataset.
img = test_images[1]

print(img.shape)
# Out:
# (28, 28)

# %%
# Add the image to a batch where it's the only member.
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = probability_model.predict(img)

print(predictions_single)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [[3.0935120e-03 5.8092034e-18 9.9466586e-01 5.7990153e-19 2.2273657e-03
#   2.3917616e-11 1.3322042e-05 6.7219990e-19 6.0550501e-13 2.8999176e-14]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# 2
